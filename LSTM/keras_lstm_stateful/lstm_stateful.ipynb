# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.metrics import mean_squared_error
from math import sqrt


def gen_uniform_amp(amp=1.0, xn=10000):
    """Generates uniform random data between
    -amp and +amp
    and of length xn
    Arguments:
        amp: maximum/minimum range of uniform data
        xn: length of series
    """
    data_input = np.random.uniform(-1 * amp, +1 * amp, xn)
    data_input = pd.DataFrame(data_input)
    return data_input


def create_model(stateful, lahead, batch_size):
    model = Sequential()
    model.add(LSTM(20,
              input_shape=(lahead, 1),
              batch_size=batch_size,
              stateful=stateful))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam')
    return model


def split_data(x, y, input_len, batch_size, ratio=0.8):
    to_train = int(input_len * ratio)
    # tweak to match with batch_size
    to_train -= to_train % batch_size

    x_train = x[:to_train]
    y_train = y[:to_train]
    x_test = x[to_train:]
    y_test = y[to_train:]

    # tweak to match with batch_size
    to_drop = x.shape[0] % batch_size
    if to_drop > 0:
        x_test = x_test[:-1 * to_drop]
        y_test = y_test[:-1 * to_drop]

    # some reshaping
    reshape_3 = lambda x: x.values.reshape((x.shape[0], x.shape[1], 1))
    x_train = reshape_3(x_train)
    x_test = reshape_3(x_test)

    reshape_2 = lambda x: x.values.reshape((x.shape[0], 1))
    y_train = reshape_2(y_train)
    y_test = reshape_2(y_test)

    return (x_train, y_train), (x_test, y_test)


def main(input_len=1000, tsteps=2, lahead=1, batch_size=1, epochs=10):
    np.random.seed(1986)
    print('Generating Data...')
    to_drop = max(tsteps - 1, lahead - 1)
    data_input = gen_uniform_amp(amp=0.1, xn=input_len + to_drop)
    # set the target to be a N-point average of the input
    expected_output = data_input.rolling(window=tsteps, center=False).mean()
    if lahead > 1:
        data_input = np.repeat(data_input.values, repeats=lahead, axis=1)
        data_input = pd.DataFrame(data_input)
        for i, c in enumerate(data_input.columns):
            data_input[c] = data_input[c].shift(i)
    # drop the nan
    expected_output = expected_output[to_drop:]
    data_input = data_input[to_drop:]
    print('Creating Stateful Model...')
    model_stateful = create_model(stateful=True, lahead=lahead, batch_size=batch_size)
    (x_train, y_train), (x_test, y_test) = split_data(data_input, expected_output, input_len, batch_size)
    print('Training Stateful Model...')
    for i in range(epochs):
        model_stateful.fit(x_train,
                           y_train,
                           batch_size=batch_size,
                           epochs=1,
                           verbose=1,
                           validation_data=(x_test, y_test),
                           shuffle=False)
        model_stateful.reset_states()
    predicted_stateful = model_stateful.predict(x_test, batch_size=batch_size)

    print('Creating Stateless Model...')
    model_stateless = create_model(stateful=False, lahead=lahead, batch_size=batch_size)

    print('Training Stateless Model...')
    model_stateless.fit(x_train,
                        y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        verbose=1,
                        validation_data=(x_test, y_test),
                        shuffle=False)
    predicted_stateless = model_stateless.predict(x_test, batch_size=batch_size)
    # RMSE
    stateless_rmse = sqrt(mean_squared_error(y_test, predicted_stateless))
    stateful_rmse = sqrt(mean_squared_error(y_test, predicted_stateful))
    print('>>> Stateful RMSE: %f' % stateful_rmse)
    print('>>> Stateless RMSE: %f' % stateless_rmse)
# Out:
# Using TensorFlow backend.

# %%
main(input_len=1000, tsteps=2, lahead=1, batch_size=1, epochs=10)
# Out:
# Generating Data...
# Creating Stateful Model...
# Training Stateful Model...
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 2s 2ms/step - loss: 6.0338e-04 - val_loss: 5.2130e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 2s 2ms/step - loss: 3.0422e-04 - val_loss: 2.6662e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 2s 3ms/step - loss: 2.4787e-04 - val_loss: 2.2040e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 2s 3ms/step - loss: 2.4690e-04 - val_loss: 2.1002e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 2s 3ms/step - loss: 2.5166e-04 - val_loss: 2.0341e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 2s 3ms/step - loss: 2.4603e-04 - val_loss: 2.0273e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 2s 3ms/step - loss: 2.5160e-04 - val_loss: 2.0657e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 2s 3ms/step - loss: 2.5648e-04 - val_loss: 2.0326e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 2s 3ms/step - loss: 2.4301e-04 - val_loss: 2.1463e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 2s 3ms/step - loss: 2.5830e-04 - val_loss: 2.1566e-04
# Creating Stateless Model...
# Training Stateless Model...
# Train on 800 samples, validate on 200 samples
# Epoch 1/10
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 2/10
# 800/800 [==============================] - 2s 2ms/step - loss: 8.5858e-04 - val_loss: 0.0010
# Epoch 3/10
# 800/800 [==============================] - 2s 2ms/step - loss: 8.5562e-04 - val_loss: 0.0010
# Epoch 4/10
# 800/800 [==============================] - 2s 2ms/step - loss: 8.5408e-04 - val_loss: 9.9552e-04
# Epoch 5/10
# 800/800 [==============================] - 2s 2ms/step - loss: 8.5305e-04 - val_loss: 9.8789e-04
# Epoch 6/10
# 800/800 [==============================] - 2s 2ms/step - loss: 8.5233e-04 - val_loss: 9.8184e-04
# Epoch 7/10
# 800/800 [==============================] - 1s 2ms/step - loss: 8.5168e-04 - val_loss: 9.7662e-04
# Epoch 8/10
# 800/800 [==============================] - 1s 2ms/step - loss: 8.5111e-04 - val_loss: 9.7196e-04
# Epoch 9/10
# 800/800 [==============================] - 2s 3ms/step - loss: 8.5060e-04 - val_loss: 9.6780e-04
# Epoch 10/10
# 800/800 [==============================] - 2s 3ms/step - loss: 8.5016e-04 - val_loss: 9.6402e-04
# >>> Stateful RMSE: 0.014813
# >>> Stateless RMSE: 0.031049

# %%
main(input_len=1000, tsteps=2, lahead=2, batch_size=1, epochs=10)
# Out:
# Generating Data...
# Creating Stateful Model...
# Training Stateful Model...
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 3s 4ms/step - loss: 4.2033e-04 - val_loss: 2.6419e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 3s 3ms/step - loss: 1.7813e-04 - val_loss: 1.4733e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 3s 3ms/step - loss: 1.0431e-04 - val_loss: 1.1480e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 2s 3ms/step - loss: 1.0678e-04 - val_loss: 1.3304e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 3s 3ms/step - loss: 8.9428e-05 - val_loss: 6.7338e-05
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 2s 3ms/step - loss: 8.3703e-05 - val_loss: 0.0021
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 2s 3ms/step - loss: 7.2679e-05 - val_loss: 1.0771e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 2s 3ms/step - loss: 7.8899e-05 - val_loss: 2.7070e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 2s 3ms/step - loss: 6.9404e-05 - val_loss: 1.5114e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 2s 3ms/step - loss: 5.6410e-05 - val_loss: 2.2002e-05
# Creating Stateless Model...
# Training Stateless Model...
# Train on 800 samples, validate on 200 samples
# Epoch 1/10
# 800/800 [==============================] - 3s 3ms/step - loss: 2.4874e-04 - val_loss: 2.2085e-08
# Epoch 2/10
# 800/800 [==============================] - 3s 3ms/step - loss: 1.7796e-09 - val_loss: 4.1078e-10
# Epoch 3/10
# 800/800 [==============================] - 3s 3ms/step - loss: 6.2476e-10 - val_loss: 8.5790e-10
# Epoch 4/10
# 800/800 [==============================] - 3s 3ms/step - loss: 8.0581e-10 - val_loss: 3.2751e-10
# Epoch 5/10
# 800/800 [==============================] - 3s 3ms/step - loss: 1.2646e-09 - val_loss: 2.6157e-09
# Epoch 6/10
# 800/800 [==============================] - 3s 3ms/step - loss: 6.0505e-09 - val_loss: 4.1339e-09
# Epoch 7/10
# 800/800 [==============================] - 3s 3ms/step - loss: 7.5263e-07 - val_loss: 5.0795e-06
# Epoch 8/10
# 800/800 [==============================] - 3s 3ms/step - loss: 3.1290e-07 - val_loss: 4.6099e-10
# Epoch 9/10
# 800/800 [==============================] - 2s 3ms/step - loss: 2.6132e-06 - val_loss: 7.7767e-10
# Epoch 10/10
# 800/800 [==============================] - 2s 3ms/step - loss: 2.3200e-09 - val_loss: 3.4153e-08
# >>> Stateful RMSE: 0.011407
# >>> Stateless RMSE: 0.000185

# %%
main(input_len=1000, tsteps=2, lahead=2, batch_size=2, epochs=10)
# Out:
# Generating Data...
# Creating Stateful Model...
# Training Stateful Model...
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 2s 2ms/step - loss: 5.7222e-04 - val_loss: 3.3209e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 1s 1ms/step - loss: 2.7512e-04 - val_loss: 2.5846e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 1s 1ms/step - loss: 2.1867e-04 - val_loss: 2.0454e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 1s 1ms/step - loss: 1.6616e-04 - val_loss: 1.4092e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 1s 1ms/step - loss: 1.2200e-04 - val_loss: 1.4021e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 1s 1ms/step - loss: 1.3346e-04 - val_loss: 1.2911e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 1s 1ms/step - loss: 1.2499e-04 - val_loss: 1.1519e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 1s 1ms/step - loss: 1.1836e-04 - val_loss: 1.1079e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 1s 1ms/step - loss: 1.1414e-04 - val_loss: 1.0658e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 1s 1ms/step - loss: 1.0990e-04 - val_loss: 1.0125e-04
# Creating Stateless Model...
# Training Stateless Model...
# Train on 800 samples, validate on 200 samples
# Epoch 1/10
# 800/800 [==============================] - 2s 2ms/step - loss: 4.3016e-04 - val_loss: 1.1322e-05
# Epoch 2/10
# 800/800 [==============================] - 1s 2ms/step - loss: 1.5174e-06 - val_loss: 2.4434e-09
# Epoch 3/10
# 800/800 [==============================] - 1s 1ms/step - loss: 7.6169e-10 - val_loss: 9.2029e-10
# Epoch 4/10
# 800/800 [==============================] - 1s 1ms/step - loss: 7.1111e-10 - val_loss: 6.6097e-10
# Epoch 5/10
# 800/800 [==============================] - 1s 1ms/step - loss: 6.7565e-10 - val_loss: 4.0220e-10
# Epoch 6/10
# 800/800 [==============================] - 1s 1ms/step - loss: 6.1312e-10 - val_loss: 4.5828e-10
# Epoch 7/10
# 800/800 [==============================] - 1s 1ms/step - loss: 5.9058e-10 - val_loss: 5.6557e-10
# Epoch 8/10
# 800/800 [==============================] - 1s 1ms/step - loss: 5.6780e-10 - val_loss: 5.2871e-10
# Epoch 9/10
# 800/800 [==============================] - 1s 1ms/step - loss: 5.4451e-10 - val_loss: 3.1738e-10
# Epoch 10/10
# 800/800 [==============================] - 1s 1ms/step - loss: 4.7959e-10 - val_loss: 3.0622e-10
# >>> Stateful RMSE: 0.010075
# >>> Stateless RMSE: 0.000017

# %%
main(input_len=1000, tsteps=2, lahead=1, batch_size=2, epochs=10)
# Out:
# Generating Data...
# Creating Stateful Model...
# Training Stateful Model...
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0012 - val_loss: 0.0012
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 1s 1ms/step - loss: 0.0011 - val_loss: 0.0010
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 1s 1ms/step - loss: 0.0010 - val_loss: 9.6194e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 1s 1ms/step - loss: 9.5830e-04 - val_loss: 9.1806e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 1s 1ms/step - loss: 9.2466e-04 - val_loss: 8.9051e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 1s 1ms/step - loss: 9.0136e-04 - val_loss: 8.7217e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 1s 1ms/step - loss: 8.8453e-04 - val_loss: 8.5977e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 1s 1ms/step - loss: 8.7209e-04 - val_loss: 8.5119e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 1s 1ms/step - loss: 8.6273e-04 - val_loss: 8.4514e-04
# Train on 800 samples, validate on 200 samples
# Epoch 1/1
# 800/800 [==============================] - 1s 1ms/step - loss: 8.5558e-04 - val_loss: 8.4081e-04
# Creating Stateless Model...
# Training Stateless Model...
# Train on 800 samples, validate on 200 samples
# Epoch 1/10
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0011 - val_loss: 8.7953e-04
# Epoch 2/10
# 800/800 [==============================] - 1s 1ms/step - loss: 8.5011e-04 - val_loss: 8.6207e-04
# Epoch 3/10
# 800/800 [==============================] - 1s 1ms/step - loss: 8.4762e-04 - val_loss: 8.5854e-04
# Epoch 4/10
# 800/800 [==============================] - 1s 1ms/step - loss: 8.4660e-04 - val_loss: 8.5537e-04
# Epoch 5/10
# 800/800 [==============================] - 1s 1ms/step - loss: 8.4567e-04 - val_loss: 8.5263e-04
# Epoch 6/10
# 800/800 [==============================] - 1s 1ms/step - loss: 8.4483e-04 - val_loss: 8.5033e-04
# Epoch 7/10
# 800/800 [==============================] - 1s 1ms/step - loss: 8.4410e-04 - val_loss: 8.4844e-04
# Epoch 8/10
# 800/800 [==============================] - 1s 1ms/step - loss: 8.4348e-04 - val_loss: 8.4689e-04
# Epoch 9/10
# 800/800 [==============================] - 1s 1ms/step - loss: 8.4296e-04 - val_loss: 8.4564e-04
# Epoch 10/10
# 800/800 [==============================] - 1s 1ms/step - loss: 8.4251e-04 - val_loss: 8.4459e-04
# >>> Stateful RMSE: 0.028951
# >>> Stateless RMSE: 0.029062
